# %% [markdown]
# # 03 - Tutorial Titanic Survived Passangers (lazypredict)
#
# by: Irfan Imaduddin <br>
# ref: https://lazypredict.readthedocs.io/en/latest/ <br>
# contact: irfanimaduddin[at]gmail.com <br>
#
# ---

# %% [markdown]
# ## Setup

# %% [markdown]
# Import modules

# %%
import ipywidgets
import numpy as np
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt

import lazypredict
from lazypredict.Supervised import LazyClassifier

import warnings
warnings.filterwarnings("ignore")
# Out:
# d:\project\machine learning\venv\lib\site-packages\sklearn\utils\deprecation.py:143: FutureWarning: The sklearn.utils.testing module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.utils. Anything that cannot be imported from sklearn.utils is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %% [markdown]
# Read files

# %%
df_train = pd.read_csv("train_clean.csv")
df_test = pd.read_csv("test_clean.csv")
df_result = pd.read_csv("gender_submission.csv")

# %% [markdown]
# ## Inspect Data

# %%
df_train.head()
# Out:
#    Survived  Pclass  Cat_family  encoded_sex  encoded_embarked  scaled_age
# 0         0       3           1            1                 2       -0.57
# 1         1       1           1            0                 0        0.66
# 2         1       3           1            0                 2       -0.26
# 3         1       1           1            0                 2        0.43
# 4         0       3           1            1                 2        0.43

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Survived          891 non-null    int64
#  1   Pclass            891 non-null    int64
#  2   Cat_family        891 non-null    int64
#  3   encoded_sex       891 non-null    int64
#  4   encoded_embarked  891 non-null    int64
#  5   scaled_age        891 non-null    float64
# dtypes: float64(1), int64(5)
# memory usage: 41.9 KB

# %%
df_test.head()
# Out:
#    Pclass  Cat_family  encoded_sex  encoded_embarked  scaled_age
# 0       3           1            1                 1        0.39
# 1       3           1            0                 2        1.37
# 2       2           1            1                 1        2.55
# 3       3           1            1                 2       -0.20
# 4       3           1            0                 2       -0.60

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Pclass            418 non-null    int64
#  1   Cat_family        418 non-null    int64
#  2   encoded_sex       418 non-null    int64
#  3   encoded_embarked  418 non-null    int64
#  4   scaled_age        418 non-null    float64
# dtypes: float64(1), int64(4)
# memory usage: 16.5 KB

# %%
df_result.head()
# Out:
#    PassengerId  Survived
# 0          892         0
# 1          893         1
# 2          894         0
# 3          895         0
# 4          896         1

# %%
df_result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
# dtypes: int64(2)
# memory usage: 6.7 KB

# %% [markdown]
# ### Summary
#
# 1. **Variable Description** <br>
#     a. `Survived`: survival label as the **target** or **dependent** variable (`1` = survived passenger, `0` = not survived or died passenger). <br>
#     b. `Pclass`: passenger class. The values are `1`, `2` and `3` which represents for the first class (upper deck), the second class (middle deck) and the third class (lower deck), respectively. <br>
#     c. `Cat_family`: number of family abroad on the Titanic. Sum of number of siblings/spouses with parents/children. <br>
#     d. `encoded_sex`: encoded gender of passenger. (`1` for `male` and `0` for `female`) <br>
#     e. `encoded_embarked`: encoded port of embarkation for every passenger. `0` for `C` (Cherbourg), `1` for `Q` (Queenstown) and `2` for `S` (Southampton). <br>
#     f. `scaled_age`: scaled age of passenger using StandardScaler. <br><br>
#
# 2. **Feature types** <br>
#     a. **Categorical** : `Survived`, `Pclass`, `Cat_family`, `encoded_sex`, `encoded_embarked`, `scaled_age` <br>
#     b. **Numerical** : `scaled_age` <br><br>
#
# 3. **Length of dataset** <br>
#     a. `df_train` = 891 <br>
#     b. `df_test` = 418 <br>
#     c. `df_result` = 418 <br> <br>

# %% [markdown]
# ## Splitting Dataset

# %% [markdown]
# Define independent and dependent (target) features

# %%
from sklearn.model_selection import train_test_split

y = df_train['Survived']
X = df_train.drop('Survived', axis=1)

# Divide train dataset into train and validation sets
X_train, X_valid, y_train, y_valid = train_test_split(
    X, # Independent variables
    y, # Dependent variable
    test_size=0.25, # Fraction of test set
    random_state=2022 # Random number seed
)

# %% [markdown]
# Set test sets

# %%
X_test = df_test
y_test = df_result['Survived']

# %% [markdown]
# ## I am too lazy to create thousand rows of code, so I use LazyPredict
#
# There are 30+ models can be used in Lazy Predict for classification. More info, please see https://lazypredict.readthedocs.io.

# %% [markdown]
# ### Let's train the model using training and validation sets

# %% [markdown]
# Define the model

# %%
clf = LazyClassifier(
    verbose=0, 
    ignore_warnings=True,
    custom_metric=None, # Metrics by default are "Accuracy", "Balanced Accuracy", "ROC AUC", "F1 Score" and "Time Taken"
    classifiers="all" # Can be customized using list
)

# %% [markdown]
# Train the model

# %%
models_train, predictions_train = clf.fit(X_train, X_valid, y_train, y_valid)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 29/29 [00:01<00:00, 17.18it/s]

# %% [markdown]
# Print all model performances

# %%
models_train
# Out:
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# AdaBoostClassifier                 0.83               0.82     0.82      0.83
# NearestCentroid                    0.83               0.81     0.81      0.83
# RidgeClassifierCV                  0.83               0.81     0.81      0.83
# LogisticRegression                 0.83               0.81     0.81      0.83
# QuadraticDiscriminantAnalysis      0.82               0.81     0.81      0.82
# LinearDiscriminantAnalysis         0.83               0.81     0.81      0.83
# RidgeClassifier                    0.83               0.81     0.81      0.83
# LinearSVC                          0.83               0.80     0.80      0.82
# CalibratedClassifierCV             0.83               0.80     0.80      0.82
# GaussianNB                         0.81               0.80     0.80      0.81
# NuSVC                              0.83               0.79     0.79      0.82
# BernoulliNB                        0.83               0.79     0.79      0.82
# SGDClassifier                      0.82               0.79     0.79      0.81
# PassiveAggressiveClassifier        0.81               0.79     0.79      0.81
# Perceptron                         0.81               0.79     0.79      0.81
# BaggingClassifier                  0.83               0.79     0.79      0.82
# LGBMClassifier                     0.83               0.79     0.79      0.82
# RandomForestClassifier             0.81               0.79     0.79      0.81
# XGBClassifier                      0.81               0.79     0.79      0.81
# SVC                                0.83               0.78     0.78      0.82
# ExtraTreesClassifier               0.81               0.77     0.77      0.81
# ExtraTreeClassifier                0.81               0.77     0.77      0.80
# DecisionTreeClassifier             0.80               0.76     0.76      0.80
# LabelSpreading                     0.81               0.76     0.76      0.80
# LabelPropagation                   0.81               0.76     0.76      0.80
# KNeighborsClassifier               0.80               0.75     0.75      0.79
# DummyClassifier                    0.62               0.60     0.60      0.63
#
#                                Time Taken
# Model
# AdaBoostClassifier                   0.10
# NearestCentroid                      0.01
# RidgeClassifierCV                    0.01
# LogisticRegression                   0.02
# QuadraticDiscriminantAnalysis        0.01
# LinearDiscriminantAnalysis           0.01
# RidgeClassifier                      0.01
# LinearSVC                            0.02
# CalibratedClassifierCV               0.08
# GaussianNB                           0.01
# NuSVC                                0.03
# BernoulliNB                          0.02
# SGDClassifier                        0.02
# PassiveAggressiveClassifier          0.01
# Perceptron                           0.01
# BaggingClassifier                    0.04
# LGBMClassifier                       0.11
# RandomForestClassifier               0.18
# XGBClassifier                        0.63
# SVC                                  0.02
# ExtraTreesClassifier                 0.16
# ExtraTreeClassifier                  0.02
# DecisionTreeClassifier               0.02
# LabelSpreading                       0.03
# LabelPropagation                     0.03
# KNeighborsClassifier                 0.02
# DummyClassifier                      0.01

# %% [markdown]
# Plot accuracy scores

# %%
plt.figure(figsize=(5, 10))
sns.set_theme(style="whitegrid")
ax = sns.barplot(data=models_train, x="Accuracy", y=models_train.index)
plt.show()

# %% [markdown]
# ### Now test the model using training and test sets

# %% [markdown]
# Define the model

# %%
clf = LazyClassifier(
    verbose=0, 
    ignore_warnings=True,
    custom_metric=None, # Metrics by default are "Accuracy", "Balanced Accuracy", "ROC AUC", "F1 Score" and "Time Taken"
    classifiers="all" # Can be customized using list
)

# %% [markdown]
# Test the model

# %%
models_test, predictions_test = clf.fit(X, X_test, y, y_test)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 29/29 [00:01<00:00, 23.26it/s]

# %% [markdown]
# Print all model performances

# %%
models_test
# Out:
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# BernoulliNB                        0.99               0.98     0.98      0.99
# NuSVC                              0.98               0.97     0.97      0.98
# PassiveAggressiveClassifier        0.96               0.97     0.97      0.96
# LinearSVC                          0.97               0.97     0.97      0.97
# LinearDiscriminantAnalysis         0.97               0.97     0.97      0.97
# CalibratedClassifierCV             0.97               0.97     0.97      0.97
# RidgeClassifierCV                  0.97               0.96     0.96      0.97
# RidgeClassifier                    0.97               0.96     0.96      0.97
# LogisticRegression                 0.95               0.95     0.95      0.95
# NearestCentroid                    0.92               0.93     0.93      0.92
# AdaBoostClassifier                 0.93               0.93     0.93      0.93
# Perceptron                         0.91               0.92     0.92      0.91
# SVC                                0.93               0.92     0.92      0.93
# GaussianNB                         0.90               0.91     0.91      0.90
# QuadraticDiscriminantAnalysis      0.88               0.90     0.90      0.88
# LabelSpreading                     0.88               0.86     0.86      0.88
# LabelPropagation                   0.88               0.86     0.86      0.88
# LGBMClassifier                     0.81               0.82     0.82      0.82
# XGBClassifier                      0.81               0.82     0.82      0.81
# KNeighborsClassifier               0.80               0.81     0.81      0.80
# ExtraTreeClassifier                0.80               0.80     0.80      0.80
# RandomForestClassifier             0.79               0.80     0.80      0.79
# ExtraTreesClassifier               0.78               0.78     0.78      0.78
# BaggingClassifier                  0.76               0.77     0.77      0.76
# SGDClassifier                      0.73               0.76     0.76      0.74
# DecisionTreeClassifier             0.73               0.74     0.74      0.74
# DummyClassifier                    0.56               0.53     0.53      0.56
#
#                                Time Taken
# Model
# BernoulliNB                          0.01
# NuSVC                                0.04
# PassiveAggressiveClassifier          0.02
# LinearSVC                            0.03
# LinearDiscriminantAnalysis           0.01
# CalibratedClassifierCV               0.09
# RidgeClassifierCV                    0.01
# RidgeClassifier                      0.02
# LogisticRegression                   0.01
# NearestCentroid                      0.01
# AdaBoostClassifier                   0.11
# Perceptron                           0.02
# SVC                                  0.03
# GaussianNB                           0.02
# QuadraticDiscriminantAnalysis        0.01
# LabelSpreading                       0.05
# LabelPropagation                     0.04
# LGBMClassifier                       0.13
# XGBClassifier                        0.07
# KNeighborsClassifier                 0.03
# ExtraTreeClassifier                  0.01
# RandomForestClassifier               0.20
# ExtraTreesClassifier                 0.16
# BaggingClassifier                    0.04
# SGDClassifier                        0.02
# DecisionTreeClassifier               0.01
# DummyClassifier                      0.01

# %% [markdown]
# Plot accuracy scores

# %%
plt.figure(figsize=(5, 10))
sns.set_theme(style="whitegrid")
ax = sns.barplot(data=models_test, x="Accuracy", y=models_test.index)
plt.show()
